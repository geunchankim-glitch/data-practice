# %%
import pandas as pd
import os

os.chdir("/Users/jaeeunlee/data-practice")
results = pd.read_csv("data/results.csv")
races = pd.read_csv("data/races.csv")
constructors = pd.read_csv("data/constructors.csv")

# %%
results["position"] = pd.to_numeric(results["position"], errors="coerce")

wins = results[results["position"] == 1]

wins = wins.merge(
    races[["raceId", "year"]],
    on="raceId",
    how="left"
)

wins = wins.merge(
    constructors[["constructorId", "name"]],
    on="constructorId",
    how="left"
)

# %%
wins["decade"] = (wins["year"] // 10) * 10
wins["decade"] = wins["decade"].astype(str) + "s"

wins_by_decade = (
    wins
    .groupby(["decade", "name"])
    .size()
    .reset_index(name="wins")
    .sort_values(["decade", "wins"], ascending=[True, False])
)

wins_by_decade.head(20)
# Out:
#    decade           name  wins
# 5   1950s        Ferrari    30
# 0   1950s     Alfa Romeo    11
# 10  1950s        Vanwall    10
# 8   1950s       Maserati     9
# 9   1950s       Mercedes     9
# 3   1950s  Cooper-Climax     5
# 6   1950s   Kurtis Kraft     5
# 2   1950s         Cooper     2
# 4   1950s        Epperly     2
# 11  1950s         Watson     2
# 1   1950s            BRM     1
# 7   1950s          Kuzma     1
# 22  1960s   Lotus-Climax    22
# 19  1960s        Ferrari    13
# 12  1960s            BRM    12
# 23  1960s     Lotus-Ford    11
# 24  1960s     Matra-Ford     9
# 15  1960s  Brabham-Repco     8
# 16  1960s  Cooper-Climax     7
# 25  1960s   McLaren-Ford     4

# %%
wins_pivot = (
    wins_by_decade
    .pivot(
        index="name",
        columns="decade",
        values="wins"
    )
    .fillna(0)
    .astype(int)
)

wins_pivot
# Out:
# decade           1950s  1960s  1970s  1980s  1990s  2000s  2010s  2020s
# name
# Alfa Romeo          11      0      0      0      0      0      0      0
# AlphaTauri           0      0      0      0      0      0      0      1
# Alpine F1 Team       0      0      0      0      0      0      0      1
# BMW Sauber           0      0      0      0      0      1      0      0
# BRM                  1     12      4      0      0      0      0      0
# Benetton             0      0      0      2     25      0      0      0
# Brabham              0      0      8     15      0      0      0      0
# Brabham-Climax       0      2      0      0      0      0      0      0
# Brabham-Ford         0      2      0      0      0      0      0      0
# Brabham-Repco        0      8      0      0      0      0      0      0
# Brawn                0      0      0      0      0      8      0      0
# Cooper               2      0      0      0      0      0      0      0
# Cooper-Climax        5      7      0      0      0      0      0      0
# Cooper-Maserati      0      2      0      0      0      0      0      0
# Eagle-Weslake        0      1      0      0      0      0      0      0
# Epperly              2      0      0      0      0      0      0      0
# Ferrari             30     13     37     18     28     85     28     10
# Hesketh              0      0      1      0      0      0      0      0
# Honda                0      2      0      0      0      1      0      0
# Jordan               0      0      0      0      3      1      0      0
# Kurtis Kraft         5      0      0      0      0      0      0      0
# Kuzma                1      0      0      0      0      0      0      0
# Ligier               0      0      4      4      1      0      0      0
# Lotus F1             0      0      0      0      0      0      2      0
# Lotus-BRM            0      1      0      0      0      0      0      0
# Lotus-Climax         0     22      0      0      0      0      0      0
# Lotus-Ford           0     11      0      0      0      0      0      0
# March                0      0      3      0      0      0      0      0
# Maserati             9      0      0      0      0      0      0      0
# Matra-Ford           0      9      0      0      0      0      0      0
# McLaren              0      0     20     56     43     41     18      7
# McLaren-Ford         0      4      0      0      0      0      0      0
# Mercedes             9      0      0      0      0      0     93     27
# Penske               0      0      1      0      0      0      0      0
# Porsche              0      1      0      0      0      0      0      0
# Racing Point         0      0      0      0      0      0      0      1
# Red Bull             0      0      0      0      0      6     56     60
# Renault              0      0      1     14      0     20      0      0
# Shadow               0      0      1      0      0      0      0      0
# Stewart              0      0      0      0      1      0      0      0
# Team Lotus           0      2     35      8      0      0      0      0
# Toro Rosso           0      0      0      0      0      1      0      0
# Tyrrell              0      0     21      2      0      0      0      0
# Vanwall             10      0      0      0      0      0      0      0
# Watson               2      1      0      0      0      0      0      0
# Williams             0      0      5     37     61     10      1      0
# Wolf                 0      0      3      0      0      0      0      0
