# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import os

os.chdir("/Users/jaeeunlee/data-practice")
drivers = pd.read_csv("data/drivers.csv")
results = pd.read_csv("data/results.csv")

# %%
# --- 1. results.csv ---
results_cols = ['milliseconds', 'fastestLapTime', 'fastestLapSpeed']

print("=== results.csv ===")
print(f"Total rows: {len(results)}\n")

for col in results_cols:
    n_missing = (results[col].astype(str) == '\\N').sum()
    pct = n_missing / len(results) * 100
    print(f"{col}: {n_missing} missing ({pct:.2f}%)")
# Out:
# === results.csv ===
# Total rows: 26759
#
# milliseconds: 19079 missing (71.30%)
# fastestLapTime: 18507 missing (69.16%)
# fastestLapSpeed: 18507 missing (69.16%)

# %%
# --- 2. drivers.csv ---
drivers_cols = ['dob', 'nationality']

print("\n=== drivers.csv ===")
print(f"Total rows: {len(drivers)}\n")

for col in drivers_cols:
    n_missing = (drivers[col].astype(str) == '\\N').sum()
    pct = n_missing / len(drivers) * 100
    print(f"{col}: {n_missing} missing ({pct:.2f}%)")
# Out:
# === drivers.csv ===
# Total rows: 861
#
# dob: 0 missing (0.00%)
# nationality: 0 missing (0.00%)

# %% [markdown]
# # The reason why results.csv includes

# %%
# --- Optional: preview affected rows ---
print("\nSample rows missing fastestLapTime in results.csv:")
display(results[results['fastestLapTime'].astype(str) == '\\N'].head())

print("\nSample rows missing dob in drivers.csv:")
display(drivers[drivers['dob'].astype(str) == '\\N'].head())
# Out:
# Sample rows missing fastestLapTime in results.csv:
#     resultId  raceId  driverId  constructorId number  grid position  \
# 16        17      18        17              9     10    14       \N
# 17        18      18        18             11     16    12       \N
# 18        19      18        19              8     19    21       \N
# 19        20      18        20              5     15     9       \N
# 20        21      18        21             10     21    16       \N
#
#    positionText  positionOrder  points  laps time milliseconds fastestLap  \
# 16            R             17     0.0     0   \N           \N         \N
# 17            R             18     0.0     0   \N           \N         \N
# 18            R             19     0.0     0   \N           \N         \N
# 19            R             20     0.0     0   \N           \N         \N
# 20            R             21     0.0     0   \N           \N         \N
#
#    rank fastestLapTime fastestLapSpeed  statusId
# 16   \N             \N              \N         4
# 17   \N             \N              \N         4
# 18   \N             \N              \N         4
# 19   \N             \N              \N         4
# 20   \N             \N              \N         4
# Sample rows missing dob in drivers.csv:
# Empty DataFrame
# Columns: [driverId, driverRef, number, code, forename, surname, dob, nationality, url]
# Index: []
